# %% [markdown]
# <a href="https://colab.research.google.com/github/online-courses-materials/OsLab/blob/main/OSlab_session_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile enhanced_server_health_check.sh
#
# #!/bin/bash
#
# # Enhanced Server Health Checkup Script
# # Author: Senior Ubuntu Developer and Professor
#
# echo "================ Server Health Checkup ================"
#
# # Function to check running processes
# check_running_processes() {
#   echo "------ Checking Running Processes ------"
#
#   # Top 5 CPU-consuming processes
#   echo "1. Processes consuming more than 10% CPU:"
#   ps aux --sort=-%cpu | awk 'NR<=5 {print $0}'
#
#   # List all running 'java' processes
#   echo "2. List all running 'java' processes:"
#   ps aux | grep 'java'
#
#   # List all running 'http' processes
#   echo "3. List all running 'http' processes:"
#   ps aux | grep 'http'
#
#   # List all running 'mysql' processes
#   echo "4. List all running 'mysql' processes:"
#   ps aux | grep 'mysql'
#
#   # Count of all running processes
#   echo "5. Total number of running processes:"
#   ps -e | wc -l
# }
#
# # Function to check CPU utilization
# check_cpu_utilization() {
#   echo "------ Checking CPU Utilization ------"
#
#   # CPU utilization of critical processes
#   echo "1. CPU utilization of critical processes:"
#   ps -eo %cpu,command | egrep '(java|http|mysql)' | awk '$1 > 10 {print $0}'
#
#   # Average CPU load in the last minute
#   echo "2. Average CPU load in the last minute:"
#   uptime | awk '{print $10}'
#
#   # CPU info
#   echo "3. CPU info:"
#   lscpu
#
#   # Top 5 CPU-consuming users
#   echo "4. Top 5 CPU-consuming users:"
#   top -b -n 1 | grep '^%Cpu' | tail -n 5
#
#   # Check CPU core count
#   echo "5. CPU core count:"
#   nproc
# }
#
# # Function to check memory utilization
# check_memory_utilization() {
#   echo "------ Checking Memory Utilization ------"
#
#   # Freeing up cache
#   echo "1. Freeing up cache:"
#   sync && echo 3 > /proc/sys/vm/drop_caches
#
#   # Display free memory
#   echo "2. Display free memory:"
#   free -h
#
#   # Display swap usage
#   echo "3. Display swap usage:"
#   swapon --show
#
#   # Display top 5 memory-consuming processes
#   echo "4. Top 5 memory-consuming processes:"
#   ps aux --sort=-%mem | awk 'NR<=5 {print $0}'
#
#   # Display available memory in megabytes
#   echo "5. Available memory in megabytes:"
#   free -m | awk 'NR==2 {print $7}'
# }
#
# # Function to check for zombie processes
# check_zombie_processes() {
#   echo "------ Checking Zombie Processes ------"
#
#   # Killing zombie processes
#   echo "1. Killing zombie processes:"
#   ps aux | awk '$8=="Z" {print "kill -9 " $2}' | sh
#
#   # List all zombie processes
#   echo "2. List all zombie processes:"
#   ps aux | awk '$8=="Z"'
#
#   # Count of zombie processes
#   echo "3. Count of zombie processes:"
#   ps aux | awk '$8=="Z"' | wc -l
#
#   # Parent processes of zombies
#   echo "4. Parent processes of zombies:"
#   ps aux | awk '$8=="Z" {print $3}'
#
#   # User owning zombie processes
#   echo "5. User owning zombie processes:"
#   ps aux | awk '$8=="Z" {print $1}'
# }
#
# # Function to check load average
# check_load_average() {
#   echo "------ Checking Load Average ------"
#
#   # Current load average
#   echo "1. Current load average:"
#   uptime
#
#   # Load average of the last 5 minutes
#   echo "2. Load average of the last 5 minutes:"
#   uptime | awk '{print $11}'
#
#   # Load average of the last 15 minutes
#   echo "3. Load average of the last 15 minutes:"
#   uptime | awk '{print $12}'
#
#   # Number of currently running processes
#   echo "4. Number of currently running processes:"
#   uptime | awk '{print $6}'
#
#   # Number of users currently logged in
#   echo "5. Number of users currently logged in:"
#   uptime | awk '{print $4}'
# }
#
# # Function to check Disk/SAN/NAS utilization
# check_disk_utilization() {
#   echo "------ Checking Disk/SAN/NAS Utilization ------"
#
#   # Disk I/O statistics
#   echo "1. Disk I/O statistics:"
#   iostat
#
#   # Disk usage
#   echo "2. Disk usage:"
#   df -h
#
#   # Inode usage
#   echo "3. Inode usage:"
#   df -i
#
#   # List mounted filesystems
#   echo "4. List mounted filesystems:"
#   mount | column -t
#
#   # Display disk partitions and sizes
#   echo "5. Display disk partitions and sizes:"
#   fdisk -l
# }
#
# # Main function to call all checks
# main() {
#   check_running_processes
#   check_cpu_utilization
#   check_memory_utilization
#   check_zombie_processes
#   check_load_average
#   check_disk_utilization
# }
#
# # Execute main function
# main
# Out:
# Writing enhanced_server_health_check.sh

# %%
# Make the script executable
# !chmod +x enhanced_server_health_check.sh

# %%
# Run the script
# !./enhanced_server_health_check.sh
# Out:
# ================ Server Health Checkup ================
# ------ Checking Running Processes ------
# 1. Processes consuming more than 10% CPU:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root          60  1.6  0.0      0     0 ?        Z    06:33   0:07 [python3] <defunct>
# root         273  1.1  0.8 878592 111368 ?       Sl   06:34   0:04 node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:d6cfe22d9e441d8863dac8b3498699e726575a4a0d
# root          78  1.0  1.2 559564 164448 ?       Sl   06:33   0:04 /usr/bin/python3 /usr/local/bin/jupyter-notebook --debug --transport="ipc" --ip=172.28.0.12 --NotebookApp.token= --port=9000 --FileContentsManager.root_dir=/ --MappingKernelManager.root_dir=/content
# root         208  0.7  0.7 1099196 95780 ?       Ssl  06:34   0:02 /usr/bin/python3 -m colab_kernel_launcher -f /root/.local/share/jupyter/runtime/kernel-313791ff-378d-47cf-960a-30fa4317d8c5.json
# 2. List all running 'java' processes:
# root        1868  0.0  0.0   6480  2228 ?        S    06:40   0:00 grep java
# 3. List all running 'http' processes:
# root          33  0.0  0.0 1237508 13104 ?       Sl   06:33   0:00 /usr/colab/bin/kernel_manager_proxy --listen_port=6000 --target_port=9000 --logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-1l2xq0qe16vdg --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true
# root         268  0.0  0.1 1237252 15360 ?       Sl   06:34   0:00 /usr/colab/bin/language_service --language_services_request_root_url=http://172.28.0.1:8013/ --language_services_request_timeout=30s -- node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:d6cfe22d9e441d8863dac8b3498699e726575a4a0d
# root        1870  0.0  0.0   6480  2232 ?        S    06:40   0:00 grep http
# 4. List all running 'mysql' processes:
# root        1872  0.0  0.0   6480  2400 ?        S    06:40   0:00 grep mysql
# 5. Total number of running processes:
# 19
# ------ Checking CPU Utilization ------
# 1. CPU utilization of critical processes:
# 2. Average CPU load in the last minute:
# 0.27,
# 3. CPU info:
# Architecture:            x86_64
#   CPU op-mode(s):        32-bit, 64-bit
#   Address sizes:         46 bits physical, 48 bits virtual
#   Byte Order:            Little Endian
# CPU(s):                  2
#   On-line CPU(s) list:   0,1
# Vendor ID:               GenuineIntel
#   Model name:            Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:          6
#     Model:               79
#     Thread(s) per core:  2
#     Core(s) per socket:  1
#     Socket(s):           1
#     Stepping:            0
#     BogoMIPS:            4399.99
#     Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mc
#                          a cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscal
#                          l nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopo
#                          logy nonstop_tsc cpuid tsc_known_freq pni pclmulqdq sss
#                          e3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes
#                          xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefe
#                          tch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_ad
#                          just bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed ad
#                          x smap xsaveopt arat md_clear arch_capabilities
# Virtualization features:
#   Hypervisor vendor:     KVM
#   Virtualization type:   full
# Caches (sum of all):
#   L1d:                   32 KiB (1 instance)
#   L1i:                   32 KiB (1 instance)
#   L2:                    256 KiB (1 instance)
#   L3:                    55 MiB (1 instance)
# NUMA:
#   NUMA node(s):          1
#   NUMA node0 CPU(s):     0,1
# Vulnerabilities:
#   Itlb multihit:         Not affected
#   L1tf:                  Mitigation; PTE Inversion
#   Mds:                   Vulnerable; SMT Host state unknown
#   Meltdown:              Vulnerable
#   Mmio stale data:       Vulnerable
#   Retbleed:              Vulnerable
#   Spec store bypass:     Vulnerable
#   Spectre v1:            Vulnerable: __user pointer sanitization and usercopy ba
#                          rriers only; no swapgs barriers
#   Spectre v2:            Vulnerable, IBPB: disabled, STIBP: disabled, PBRSB-eIBR
#                          S: Not affected
#   Srbds:                 Not affected
#   Tsx async abort:       Vulnerable
# 4. Top 5 CPU-consuming users:
# %Cpu(s):  0.0 us,  0.0 sy,  0.0 ni,100.0 id,  0.0 wa,  0.0 hi,  0.0 si,  0.0 st
# 5. CPU core count:
# 2
# ------ Checking Memory Utilization ------
# 1. Freeing up cache:
# ./enhanced_server_health_check.sh: line 65: /proc/sys/vm/drop_caches: Read-only file system
# 2. Display free memory:
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       576Mi       9.2Gi       1.0Mi       2.9Gi        11Gi
# Swap:             0B          0B          0B
# 3. Display swap usage:
# 4. Top 5 memory-consuming processes:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root          78  1.0  1.2 559564 164448 ?       Sl   06:33   0:04 /usr/bin/python3 /usr/local/bin/jupyter-notebook --debug --transport="ipc" --ip=172.28.0.12 --NotebookApp.token= --port=9000 --FileContentsManager.root_dir=/ --MappingKernelManager.root_dir=/content
# root         273  1.1  0.8 878592 111368 ?       Sl   06:34   0:04 node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:d6cfe22d9e441d8863dac8b3498699e726575a4a0d
# root         208  0.7  0.7 1100084 95780 ?       Ssl  06:34   0:02 /usr/bin/python3 -m colab_kernel_launcher -f /root/.local/share/jupyter/runtime/kernel-313791ff-378d-47cf-960a-30fa4317d8c5.json
# root          61  0.1  0.3  66656 51672 ?        S    06:33   0:00 python3 /usr/local/bin/colab-fileshim.py
# 5. Available memory in megabytes:
# 12120
# ------ Checking Zombie Processes ------
# 1. Killing zombie processes:
# 2. List all zombie processes:
# root          60  1.6  0.0      0     0 ?        Z    06:33   0:07 [python3] <defunct>
# 3. Count of zombie processes:
# 1
# 4. Parent processes of zombies:
# 1.6
# 5. User owning zombie processes:
# root
# ------ Checking Load Average ------
# 1. Current load average:
#  06:40:49 up 7 min,  0 users,  load average: 0.29, 0.27, 0.16
# 2. Load average of the last 5 minutes:
# 0.16
# 3. Load average of the last 15 minutes:
#
# 4. Number of currently running processes:
# users,
# 5. Number of users currently logged in:
# min,
# ------ Checking Disk/SAN/NAS Utilization ------
# 1. Disk I/O statistics:
# ./enhanced_server_health_check.sh: line 140: iostat: command not found
# 2. Disk usage:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   27G   82G  25% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.1G  885M  55% /usr/sbin/docker-init
# tmpfs           6.4G  636K  6.4G   1% /var/colab
# /dev/sda1        44G   28G   16G  64% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# 3. Inode usage:
# Filesystem      Inodes  IUsed   IFree IUse% Mounted on
# overlay        7208960 351467 6857493    5% /
# tmpfs          1661776     17 1661759    1% /dev
# shm            1661776      1 1661775    1% /dev/shm
# /dev/root       127488  14478  113010   12% /usr/sbin/docker-init
# tmpfs          1661776     24 1661752    1% /var/colab
# /dev/sda1      2864160  12774 2851386    1% /etc/hosts
# tmpfs          1661776      1 1661775    1% /proc/acpi
# tmpfs          1661776      1 1661775    1% /proc/scsi
# tmpfs          1661776      1 1661775    1% /sys/firmware
# 4. List mounted filesystems:
# overlay    on  /                                   type  overlay  (rw,relatime,lowerdir=/var/lib/docker/overlay2/l/YAYX6EN6NFWUJG2M4XZ2FBLWJE:/var/lib/docker/overlay2/l/7BZL65NK4MYHHMQDWLEXG75AVT:/var/lib/docker/overlay2/l/G6SMTJRGG3IY47PNDTRPNQNE3T:/var/lib/docker/overlay2/l/2N5D4364VVLKDNKURCYP6N7LKJ:/var/lib/docker/overlay2/l/IE5AUDAVQGS2BCVYICAGWT7LN3:/var/lib/docker/overlay2/l/IJPIY7HCW7J5ASPMPMUXLCAPDD:/var/lib/docker/overlay2/l/RA73Q5LGYPFQBIY5JPE2PRD4IX:/var/lib/docker/overlay2/l/MB7KAANN4E7PH5CLZFKE5WEEDO:/var/lib/docker/overlay2/l/3XWUOZFSHTVM75DROUJNMTDFQJ:/var/lib/docker/overlay2/l/EYOHC4WGOBA2AZH2WYTRTOVPFD:/var/lib/docker/overlay2/l/CQJ7ALRTZUJ3NQZ3ZLO37KS7TE:/var/lib/docker/overlay2/l/R3P3AQJSKFPC7LI2DNSDEJ5DNO:/var/lib/docker/overlay2/l/KF7V42A4422L5QS4K7VLJB2E6Z:/var/lib/docker/overlay2/l/IMIICD7TGI34XBNYGTAF4ZAHRJ:/var/lib/docker/overlay2/l/23RFM7HEPXCCJZ26VVJUY7VDM5:/var/lib/docker/overlay2/l/IM5ODXHRWJ7BQGAHMMQCGPZ7AW:/var/lib/docker/overlay2/l/THNC2TEM7VGXFKEIDHQPMW3FG2:/var/lib/docker/overlay2/l/BCSC5X3IPBO3NRC6DOGBDZVQFJ:/var/lib/docker/overlay2/l/JEDPNPV4ZCVOCVQPTS25KFZN2D:/var/lib/docker/overlay2/l/SNCMFY3BSWZTBJNYN2WPODILYC:/var/lib/docker/overlay2/l/NGS3M3AUOPWDDAYYO742P5FXV4:/var/lib/docker/overlay2/l/7JB6YDHI63CY3RNWYFIMEUBGPS:/var/lib/docker/overlay2/l/TJECZYJNCTLHUZJ55HLHDWYLH2:/var/lib/docker/overlay2/l/AU7X6SMNTKUBWVSD22V2R2ZXC6:/var/lib/docker/overlay2/l/BMKAOLVRYF6HUQHZQN2ZMMIYKP:/var/lib/docker/overlay2/l/ZWN4VEI3FXZ4COX52J3EZAFC4I:/var/lib/docker/overlay2/l/XRHO4QVA5XFQK44RZQL5PZR3XH:/var/lib/docker/overlay2/l/Z4XW6YGOM4NG4LPFQ6COUZFAJU:/var/lib/docker/overlay2/l/3KJEV7Q4TNH2GTD2PPUS232KWO:/var/lib/docker/overlay2/l/D5GHCUJEBV6LTVLSV7GBFFLX77:/var/lib/docker/overlay2/l/RGXFG6HVSIFMQMIWXC3BGETWPZ:/var/lib/docker/overlay2/l/PBF3GGSYXL7DGTB6QTUYFVFDAF:/var/lib/docker/overlay2/l/2KWHQRSVGEMTG6NRYDWCQ3W7ND:/var/lib/docker/overlay2/l/VISPH3U52BZTAT2PRNQJS33NUT:/var/lib/docker/overlay2/l/QTB7M3EEVSS6JXEU4JLZ422XGY:/var/lib/docker/overlay2/l/EJFQIMEQ7CMII4MWW5JJDTQ5AN:/var/lib/docker/overlay2/l/DTZJCHKPAVS2FYUKG3AVYUJYIL:/var/lib/docker/overlay2/l/AHRYZLQXZJXECIVJKVYWUGCSUP:/var/lib/docker/overlay2/l/TAHVU5RUA4MWMYASYF7XHATUT5:/var/lib/docker/overlay2/l/TO75KTPS6VTSH4JXQZXUFOWC6U:/var/lib/docker/overlay2/l/57RXZEY5SZB4BEQGZHWBOC5ZYM:/var/lib/docker/overlay2/l/ES5CZZZQHDSI5SPJUKCNVL2EK3:/var/lib/docker/overlay2/l/UCFXKKBGAWXKABC5UKDYSZBQHM:/var/lib/docker/overlay2/l/SKAL2RPPPKQ4JEJF3IGLXCMXKS:/var/lib/docker/overlay2/l/FVNYE6N2KSXQ43XSL2M3EIBESK:/var/lib/docker/overlay2/l/7GDPMDZHINB53YKVRSWG2YRH7X:/var/lib/docker/overlay2/l/3RDRCWK5BTG5QQ44YPRD463P5N:/var/lib/docker/overlay2/l/7BVO6DDDRC7XMCANOAKCEKDAAW:/var/lib/docker/overlay2/l/NNLPLDLJEXOV5D2BBZZL3HPB7Y:/var/lib/docker/overlay2/l/AUHNZ66TUIMSJIXFOAOGEOW35F:/var/lib/docker/overlay2/l/HVM2SDNMQS3PJLQ7GNKGR3KY3V:/var/lib/docker/overlay2/l/Q2RDVLKMSRBVKVFRD53KZQJWN4:/var/lib/docker/overlay2/l/EVJ4ETK7TSRH2CVAXJ3S4VZFUS:/var/lib/docker/overlay2/l/I5YINH7537FAS6SHL6YM3T732C,upperdir=/var/lib/docker/overlay2/21fd9baf4aff578c1afb583b225f93bcd60d6ceda887a419dbe4088ec463d6b7/diff,workdir=/var/lib/docker/overlay2/21fd9baf4aff578c1afb583b225f93bcd60d6ceda887a419dbe4088ec463d6b7/work)
# proc       on  /proc                               type  proc     (rw,nosuid,nodev,noexec,relatime)
# tmpfs      on  /dev                                type  tmpfs    (rw,nosuid,size=65536k,mode=755)
# devpts     on  /dev/pts                            type  devpts   (rw,nosuid,noexec,relatime,gid=5,mode=620,ptmxmode=666)
# sysfs      on  /sys                                type  sysfs    (ro,nosuid,nodev,noexec,relatime)
# cgroup     on  /sys/fs/cgroup                      type  cgroup2  (ro,nosuid,nodev,noexec,relatime,nsdelegate,memory_recursiveprot)
# mqueue     on  /dev/mqueue                         type  mqueue   (rw,nosuid,nodev,noexec,relatime)
# shm        on  /dev/shm                            type  tmpfs    (rw,nosuid,nodev,noexec,relatime,size=5989376k)
# /dev/dm-0  on  /usr/sbin/docker-init               type  ext2     (ro,relatime)
# tmpfs      on  /var/colab                          type  tmpfs    (rw,nosuid,nodev,noexec)
# /dev/sda1  on  /etc/resolv.conf                    type  ext4     (rw,nosuid,nodev,relatime,commit=30)
# /dev/sda1  on  /etc/hostname                       type  ext4     (rw,nosuid,nodev,relatime,commit=30)
# /dev/sda1  on  /etc/hosts                          type  ext4     (rw,nosuid,nodev,relatime,commit=30)
# cgroup2    on  /var/colab/cgroup/jupyter-children  type  cgroup2  (ro,relatime,nsdelegate,memory_recursiveprot)
# proc       on  /proc/bus                           type  proc     (ro,nosuid,nodev,noexec,relatime)
# proc       on  /proc/fs                            type  proc     (ro,nosuid,nodev,noexec,relatime)
# proc       on  /proc/irq                           type  proc     (ro,nosuid,nodev,noexec,relatime)
# proc       on  /proc/sys                           type  proc     (ro,nosuid,nodev,noexec,relatime)
# proc       on  /proc/sysrq-trigger                 type  proc     (ro,nosuid,nodev,noexec,relatime)
# tmpfs      on  /proc/acpi                          type  tmpfs    (ro,relatime)
# tmpfs      on  /proc/kcore                         type  tmpfs    (rw,nosuid,size=65536k,mode=755)
# tmpfs      on  /proc/keys                          type  tmpfs    (rw,nosuid,size=65536k,mode=755)
# tmpfs      on  /proc/timer_list                    type  tmpfs    (rw,nosuid,size=65536k,mode=755)
# tmpfs      on  /proc/scsi                          type  tmpfs    (ro,relatime)
# tmpfs      on  /sys/firmware                       type  tmpfs    (ro,relatime)
# 5. Display disk partitions and sizes:
# ./enhanced_server_health_check.sh: line 156: fdisk: command not found
